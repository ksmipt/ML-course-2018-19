# %%
import pickle
import numpy as np
import PIL.Image
import itertools
from IPython.core.display import Image, display
import scipy.ndimage
import random
import numpy as np
import matplotlib.pylab as plt
import tqdm
import math
# %matplotlib inline

# %% [markdown]
# # Загружаем датасет

# %%
with open('./hw_1_train.pickle', 'rb') as f:
    train = pickle.load(f)

with open('./hw_1_test_no_lables.pickle', 'rb') as f:
    test_no_lables = pickle.load(f)

# %%
# Пример, как можно визуализировать данные
plt.imshow(train['data'][0].reshape(28,28))

# %% [markdown]
# # Обучаем модель

# %%
# Реализуйте здесь обучение модели

# %% [markdown]
# # Оцениваем результат

# %% [markdown]
# Обязательно отрисуйте 2 графика:
# - loss на обучающем и тестовом множесте
# - % правильно классифицированных примеров на тестовом и обучающем множестве

# %%
plt.title('Loss')
plt.plot([e[0] for e in tr_eval], label='train')
plt.plot([e[0] for e in te_eval], label='test')
plt.legend()

# %%
plt.title('Acc')
plt.plot([e[1] for e in tr_eval], label='train')
plt.plot([e[1] for e in te_eval], label='test')
plt.legend()

# %% [markdown]
# # Сдача

# %% [markdown]
# 1. Получаете точность не менее 95% (но врядли у вас честно может получиться больше 99%)
# 2. Проверяете, чтобы были отрисованы необходимые графики!
# 3. Сохраняете код в формате Surname.ipynb
# 4. Присылаете код на почту chilova.ks@phystech.edu
